# %%
from pyspark.sql import SparkSession

# Initialize Spark session with Iceberg configurations
spark = SparkSession.builder \
  .appName("IcebergLocalDevelopment") \
  .config('spark.jars.packages', 'org.apache.iceberg:iceberg-spark-runtime-3.5_2.12:1.5.2') \
  .config("spark.sql.extensions", "org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions") \
  .config("spark.sql.catalog.local", "org.apache.iceberg.spark.SparkCatalog") \
  .config("spark.sql.catalog.local.type", "hadoop") \
  .config("spark.sql.catalog.local.warehouse", "spark-warehouse/iceberg") \
  .getOrCreate()

# Verify Spark session creation
spark.sql("SHOW DATABASES").show()
# Out:
# 26/05/25 23:45:16 WARN Utils: Your hostname, codespaces-6913c0 resolves to a loopback address: 127.0.0.1; using 10.0.0.86 instead (on interface eth0)
# 26/05/25 23:45:16 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# :: loading settings :: url = jar:file:/workspaces/learn_iceberg/iceberg_pyspark_project/.venv/lib/python3.12/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/codespace/.ivy2/cache
# The jars for the packages stored in: /home/codespace/.ivy2/jars
# org.apache.iceberg#iceberg-spark-runtime-3.5_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-cf138812-6565-436e-b88d-e84276b08e25;1.0
# 	confs: [default]
# 	found org.apache.iceberg#iceberg-spark-runtime-3.5_2.12;1.5.2 in central
# downloading https://repo1.maven.org/maven2/org/apache/iceberg/iceberg-spark-runtime-3.5_2.12/1.5.2/iceberg-spark-runtime-3.5_2.12-1.5.2.jar ...
# 	[SUCCESSFUL ] org.apache.iceberg#iceberg-spark-runtime-3.5_2.12;1.5.2!iceberg-spark-runtime-3.5_2.12.jar (944ms)
# :: resolution report :: resolve 880ms :: artifacts dl 952ms
# 	:: modules in use:
# 	org.apache.iceberg#iceberg-spark-runtime-3.5_2.12;1.5.2 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   1   |   1   |   1   |   0   ||   1   |   1   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-cf138812-6565-436e-b88d-e84276b08e25
# 	confs: [default]
# 	1 artifacts copied, 0 already retrieved (40629kB/67ms)
# 26/05/25 23:45:19 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/05/25 23:45:21 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# +---------+
# |namespace|
# +---------+
# |  default|
# +---------+

# %%
# Create an Iceberg table
spark.sql("""
  CREATE TABLE local.schema.users (
    id INT,
    name STRING,
    age INT
  ) USING iceberg""")

# Insert some sample data
spark.sql("""
  INSERT INTO local.schema.users VALUES
    (1, 'Alice', 30),
    (2, 'Bob', 25),
    (3, 'Charlie', 35)""")

# Query the data
result = spark.sql("SELECT * FROM local.schema.users")
result.show()
# Out:
# [Stage 1:>                                                          (0 + 1) / 1]
# +---+-------+---+
# | id|   name|age|
# +---+-------+---+
# |  1|  Alice| 30|
# |  2|    Bob| 25|
# |  3|Charlie| 35|
# +---+-------+---+
